# %%
from skimage import io, data
import numpy as np
from matplotlib import pyplot as plt

# %%
image_dir = '/home/prasojo/belajar/belajar_python/BelajarData/picture/godel.jpg'
my_image = io.imread(image_dir)
plt.imshow(my_image)

# %%
random_image = np.random.random((200,200,3))
plt.imshow(random_image)

# %%
image2 = random_image * 255
image2 = np.int64(image2)
plt.imshow(image2)

# %%
print(random_image.shape)
print(hh.shape)
# Out:
# (200, 200, 3)
# (200, 200, 3)

# %%
image3 = np.int64(image2 * 0.5)
plt.imshow(image3)

# %%
plt.imshow(data.retina())
