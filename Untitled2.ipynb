# %%
import mplfinance as mpf
import pandas as pd
from matplotlib.pyplot import savefig

# %%
df_saham = pd.read_excel('/home/prasojo/belajar/BelajarData/dataset/saham/emiten/AALI.xlsx')
df_saham = df_saham.reindex(index=df_saham.index[::-1])
df_saham = df_saham.set_index(pd.DatetimeIndex(df_saham['date'].values))

# %%
df_saham
# Out:
#             Unnamed: 0   JII        date   Open   High    Low  Close   Volume
# 2020-11-20          69  AALI  2020-11-20  10975  11275  10975  11000  4112100
# 2020-11-23          68  AALI  2020-11-23  11025  11100  10900  10975  1841700
# 2020-11-24          67  AALI  2020-11-24  11000  11125  10975  11025  1886800
# 2020-11-25          66  AALI  2020-11-25  11050  11100  10800  10800  3182800
# 2020-11-26          65  AALI  2020-11-26  10800  10950  10800  10850  1693400
# ...                ...   ...         ...    ...    ...    ...    ...      ...
# 2021-03-01           4  AALI  2021-03-01  11250  11325  11025  11250  1253700
# 2021-03-02           3  AALI  2021-03-02  11250  11300  11025  11050  1108800
# 2021-03-03           2  AALI  2021-03-03  11050  11075  10950  10975  1196100
# 2021-03-04           1  AALI  2021-03-04  10975  11100  10900  10950   767700
# 2021-03-05           0  AALI  2021-03-05  10950  10950  10700  10850  1541800
#
# [70 rows x 8 columns]

# %%
mpf.plot(df_saham,type='candle',mav=(3,7),volume=True,figsize=(25,15))

# %%
xx = 'hahaha.xlsx'
yy = xx.split('.')
yy[0]
# Out:
# 'hahaha'
