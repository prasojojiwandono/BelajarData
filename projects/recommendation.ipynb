# %%
from lightfm import LightFM
# Out:
# C:\Users\GAM\miniconda3\envs\env_conda\lib\site-packages\lightfm\_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn(
