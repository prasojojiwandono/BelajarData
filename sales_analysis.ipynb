# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import combinations
from collections import Counter

# %%
files = [file for file in os.listdir('./dataset/Sales_Data')]
all_months_data = pd.DataFrame()

for file in files:
    df = pd.read_csv('./dataset/Sales_Data/'+file)
    all_months_data = pd.concat([all_months_data,df])
    
all_months_data.to_csv('./dataset/Sales_Data/all_data.csv',index=False)

# %%
all_months_data = pd.read_csv('./dataset/Sales_Data/all_data.csv')

# %%
all_months_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       236670            Wired Headphones                2      11.99
# 1       236671  Bose SoundSport Headphones                1      99.99
# 2       236672                      iPhone                1      700.0
# 3       236673       AA Batteries (4-pack)                2       3.84
# 4       236674       AA Batteries (4-pack)                2       3.84
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
all_months_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186850 entries, 0 to 18382
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 10.0+ MB

# %%
all_data = all_months_data.copy()

# %%
all_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       236670            Wired Headphones                2      11.99
# 1       236671  Bose SoundSport Headphones                1      99.99
# 2       236672                      iPhone                1      700.0
# 3       236673       AA Batteries (4-pack)                2       3.84
# 4       236674       AA Batteries (4-pack)                2       3.84
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %% [markdown]
# ## cleaning data

# %%
all_data.isna().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# Month               545
# dtype: int64

# %%
nan_df = all_data[all_data.isna().any(axis=1)]
nan_df
# Out:
#       Order ID Product Quantity Ordered Price Each Order Date  \
# 312        NaN     NaN              NaN        NaN        NaN
# 1222       NaN     NaN              NaN        NaN        NaN
# 2648       NaN     NaN              NaN        NaN        NaN
# 2685       NaN     NaN              NaN        NaN        NaN
# 3119       NaN     NaN              NaN        NaN        NaN
# ...        ...     ...              ...        ...        ...
# 16763      NaN     NaN              NaN        NaN        NaN
# 16912      NaN     NaN              NaN        NaN        NaN
# 17060      NaN     NaN              NaN        NaN        NaN
# 17446      NaN     NaN              NaN        NaN        NaN
# 17718      NaN     NaN              NaN        NaN        NaN
#
#       Purchase Address Month
# 312                NaN   NaN
# 1222               NaN   NaN
# 2648               NaN   NaN
# 2685               NaN   NaN
# 3119               NaN   NaN
# ...                ...   ...
# ...

# %%
all_data = all_data.dropna(how='all')
all_data.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# Month               0
# dtype: int64

# %%
temp_df = all_data[
    all_data['Order Date'].str[0:2] == 'Or'
]
temp_df
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 211    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 243    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1291   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1412   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1427   Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...         ...      ...               ...         ...         ...
# 15280  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 17208  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 17324  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 17339  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 17744  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#        Purchase Address Month
# 211    Purchase Address    Or
# 243    Purchase Address    Or
# 1291   Purchase Address    Or
# 1412   Purchase Address    Or
# ...

# %%
all_data = all_data[
    all_data['Order Date'].str[0:2]!= 'Or'
]
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   236670            Wired Headphones                2      11.99
# 1   236671  Bose SoundSport Headphones                1      99.99
# 2   236672                      iPhone                1      700.0
# 3   236673       AA Batteries (4-pack)                2       3.84
# 4   236674       AA Batteries (4-pack)                2       3.84
#
#        Order Date                      Purchase Address Month
# 0  08/31/19 22:21      359 Spruce St, Seattle, WA 98101    08
# 1  08/15/19 15:11        492 Ridge St, Dallas, TX 75001    08
# 2  08/06/19 14:40        149 7th St, Portland, OR 97035    08
# 3  08/29/19 20:59     631 2nd St, Los Angeles, CA 90001    08
# 4  08/15/19 19:53  736 14th St, New York City, NY 10001    08

# %% [markdown]
# ## Extract month from order date

# %%
all_data['Month']=all_data['Order Date'].str[0:2]
all_data['Month']=all_data['Month'].astype('int32')
all_data.head()
# Out:
# <ipython-input-32-50e173a66032>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Month']=all_data['Order Date'].str[0:2]
# <ipython-input-32-50e173a66032>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Month']=all_data['Month'].astype('int32')
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   236670            Wired Headphones                2      11.99
# 1   236671  Bose SoundSport Headphones                1      99.99
# ...

# %%
all_data['Quantity Ordered']=pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each']=pd.to_numeric(all_data['Price Each'])
# Out:
# <ipython-input-35-f0e4e8847aac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Quantity Ordered']=pd.to_numeric(all_data['Quantity Ordered'])
# <ipython-input-35-f0e4e8847aac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Price Each']=pd.to_numeric(all_data['Price Each'])

# %% [markdown]
# ## adding column sales (quantity x price each)

# %%
all_data['Sales']=all_data['Quantity Ordered'] * all_data['Price Each']
# Out:
# <ipython-input-36-4bb2d80b0ab6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Sales']=all_data['Quantity Ordered'] * all_data['Price Each']

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   236670            Wired Headphones                 2       11.99
# 1   236671  Bose SoundSport Headphones                 1       99.99
# 2   236672                      iPhone                 1      700.00
# 3   236673       AA Batteries (4-pack)                 2        3.84
# 4   236674       AA Batteries (4-pack)                 2        3.84
#
#        Order Date                      Purchase Address  Month   Sales
# 0  08/31/19 22:21      359 Spruce St, Seattle, WA 98101      8   23.98
# 1  08/15/19 15:11        492 Ridge St, Dallas, TX 75001      8   99.99
# 2  08/06/19 14:40        149 7th St, Portland, OR 97035      8  700.00
# 3  08/29/19 20:59     631 2nd St, Los Angeles, CA 90001      8    7.68
# 4  08/15/19 19:53  736 14th St, New York City, NY 10001      8    7.68

# %%
sales_months = all_data.\
groupby('Month').\
sum()
sales_months
# Out:
#        Quantity Ordered    Price Each         Sales
# Month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %% [markdown]
# ## from here we know the best month of sales is in december

# %%
plt.bar(sales_months.index,sales_months['Sales'])
plt.xticks(sales_months.index)
plt.xlabel('Months')
plt.ylabel('Sales in Million')
plt.show()

# %%
def get_city(address):
    return address.split(',')[1]

def get_state(address):
    return address.split(',')[2].split()[0]

all_data['City']=all_data['Purchase Address'].\
apply(lambda x: f'{get_city(x)} ({get_state(x)})')

all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   236670            Wired Headphones                 2       11.99
# 1   236671  Bose SoundSport Headphones                 1       99.99
# 2   236672                      iPhone                 1      700.00
# 3   236673       AA Batteries (4-pack)                 2        3.84
# 4   236674       AA Batteries (4-pack)                 2        3.84
#
#        Order Date                      Purchase Address  Month   Sales  \
# 0  08/31/19 22:21      359 Spruce St, Seattle, WA 98101      8   23.98
# 1  08/15/19 15:11        492 Ridge St, Dallas, TX 75001      8   99.99
# 2  08/06/19 14:40        149 7th St, Portland, OR 97035      8  700.00
# 3  08/29/19 20:59     631 2nd St, Los Angeles, CA 90001      8    7.68
# 4  08/15/19 19:53  736 14th St, New York City, NY 10001      8    7.68
#
#                   City
# 0         Seattle (WA)
# 1          Dallas (TX)
# 2        Portland (OR)
# 3     Los Angeles (CA)
# ...

# %%
sales_city = all_data.groupby('City').sum()
sales_city
# Out:
#                      Quantity Ordered    Price Each   Month         Sales
# City
#  Atlanta (GA)                   16602  2.779908e+06  104794  2.795499e+06
#  Austin (TX)                    11153  1.809874e+06   69829  1.819582e+06
#  Boston (MA)                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas (TX)                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles (CA)               33289  5.421435e+06  208325  5.452571e+06
#  New York City (NY)             27932  4.635371e+06  175741  4.664317e+06
#  Portland (ME)                   2750  4.471893e+05   17144  4.497583e+05
#  Portland (OR)                  11303  1.860558e+06   70621  1.870732e+06
#  San Francisco (CA)             50239  8.211462e+06  315520  8.262204e+06
#  Seattle (WA)                   16553  2.733296e+06  104941  2.747755e+06

# %%
plt.bar(sales_city.index, sales_city.Sales)
plt.xticks(sales_city.index,rotation ='vertical', size=8)
plt.xlabel('Cities')
plt.ylabel('Sales in Million')
plt.grid()

# %%
oo = [x for x,y in all_data.groupby('City')]
oo
# Out:
# [' Atlanta (GA)',
#  ' Austin (TX)',
#  ' Boston (MA)',
#  ' Dallas (TX)',
#  ' Los Angeles (CA)',
#  ' New York City (NY)',
#  ' Portland (ME)',
#  ' Portland (OR)',
#  ' San Francisco (CA)',
#  ' Seattle (WA)']

# %% [markdown]
# ## from here we know san fransisco is the best sales

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   236670            Wired Headphones                 2       11.99
# 1   236671  Bose SoundSport Headphones                 1       99.99
# 2   236672                      iPhone                 1      700.00
# 3   236673       AA Batteries (4-pack)                 2        3.84
# 4   236674       AA Batteries (4-pack)                 2        3.84
#
#        Order Date                      Purchase Address  Month   Sales  \
# 0  08/31/19 22:21      359 Spruce St, Seattle, WA 98101      8   23.98
# 1  08/15/19 15:11        492 Ridge St, Dallas, TX 75001      8   99.99
# 2  08/06/19 14:40        149 7th St, Portland, OR 97035      8  700.00
# 3  08/29/19 20:59     631 2nd St, Los Angeles, CA 90001      8    7.68
# 4  08/15/19 19:53  736 14th St, New York City, NY 10001      8    7.68
#
#                   City
# 0         Seattle (WA)
# 1          Dallas (TX)
# 2        Portland (OR)
# 3     Los Angeles (CA)
# ...

# %%
all_data['Order Date']=pd.to_datetime(all_data['Order Date'])

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   236670            Wired Headphones                 2       11.99
# 1   236671  Bose SoundSport Headphones                 1       99.99
# 2   236672                      iPhone                 1      700.00
# 3   236673       AA Batteries (4-pack)                 2        3.84
# 4   236674       AA Batteries (4-pack)                 2        3.84
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-08-31 22:21:00      359 Spruce St, Seattle, WA 98101      8   23.98
# 1 2019-08-15 15:11:00        492 Ridge St, Dallas, TX 75001      8   99.99
# 2 2019-08-06 14:40:00        149 7th St, Portland, OR 97035      8  700.00
# 3 2019-08-29 20:59:00     631 2nd St, Los Angeles, CA 90001      8    7.68
# 4 2019-08-15 19:53:00  736 14th St, New York City, NY 10001      8    7.68
#
#                   City
# 0         Seattle (WA)
# 1          Dallas (TX)
# 2        Portland (OR)
# ...

# %%
all_data['Hour']=all_data['Order Date'].dt.hour
all_data
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       236670            Wired Headphones                 2       11.99
# 1       236671  Bose SoundSport Headphones                 1       99.99
# 2       236672                      iPhone                 1      700.00
# 3       236673       AA Batteries (4-pack)                 2        3.84
# 4       236674       AA Batteries (4-pack)                 2        3.84
# ...        ...                         ...               ...         ...
# 18378   194090                Google Phone                 1      600.00
# 18379   194091       AA Batteries (4-pack)                 1        3.84
# 18380   194092      AAA Batteries (4-pack)                 2        2.99
# 18381   194093       AA Batteries (4-pack)                 1        3.84
# 18382   194094    Lightning Charging Cable                 1       14.95
#
#                Order Date                        Purchase Address  Month  \
# ...

# %%
all_data['Minutes']=all_data['Order Date'].dt.minute
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   236670            Wired Headphones                 2       11.99
# 1   236671  Bose SoundSport Headphones                 1       99.99
# 2   236672                      iPhone                 1      700.00
# 3   236673       AA Batteries (4-pack)                 2        3.84
# 4   236674       AA Batteries (4-pack)                 2        3.84
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-08-31 22:21:00      359 Spruce St, Seattle, WA 98101      8   23.98
# 1 2019-08-15 15:11:00        492 Ridge St, Dallas, TX 75001      8   99.99
# 2 2019-08-06 14:40:00        149 7th St, Portland, OR 97035      8  700.00
# 3 2019-08-29 20:59:00     631 2nd St, Los Angeles, CA 90001      8    7.68
# 4 2019-08-15 19:53:00  736 14th St, New York City, NY 10001      8    7.68
#
#                   City  Hour  Minutes
# 0         Seattle (WA)    22       21
# ...

# %%
sales_hourly = all_data.groupby('Hour').count()
plt.plot(sales_hourly.index, sales_hourly)

# %% [markdown]
# ## from here we know the biggest sales happen in about 11am or 7pm

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   236670            Wired Headphones                 2       11.99
# 1   236671  Bose SoundSport Headphones                 1       99.99
# 2   236672                      iPhone                 1      700.00
# 3   236673       AA Batteries (4-pack)                 2        3.84
# 4   236674       AA Batteries (4-pack)                 2        3.84
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-08-31 22:21:00      359 Spruce St, Seattle, WA 98101      8   23.98
# 1 2019-08-15 15:11:00        492 Ridge St, Dallas, TX 75001      8   99.99
# 2 2019-08-06 14:40:00        149 7th St, Portland, OR 97035      8  700.00
# 3 2019-08-29 20:59:00     631 2nd St, Los Angeles, CA 90001      8    7.68
# 4 2019-08-15 19:53:00  736 14th St, New York City, NY 10001      8    7.68
#
#                   City  Hour  Minutes
# 0         Seattle (WA)    22       21
# ...

# %%
df=all_data[all_data['Order ID'].duplicated(keep=False)]
df.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 46   236716     AA Batteries (4-pack)                 2        3.84
# 47   236716      USB-C Charging Cable                 1       11.95
# 60   236729                    iPhone                 1      700.00
# 61   236729  Apple Airpods Headphones                 1      150.00
# 62   236730              Google Phone                 1      600.00
#
#             Order Date                         Purchase Address  Month  \
# 46 2019-08-17 20:12:00     84 Cedar St, San Francisco, CA 94016      8
# 47 2019-08-17 20:12:00     84 Cedar St, San Francisco, CA 94016      8
# 60 2019-08-09 09:28:00     635 Lake St, San Francisco, CA 94016      8
# 61 2019-08-09 09:28:00     635 Lake St, San Francisco, CA 94016      8
# 62 2019-08-02 10:17:00  445 Lincoln St, New York City, NY 10001      8
#
#      Sales                 City  Hour  Minutes
# 46    7.68   San Francisco (CA)    20       12
# ...

# %%
df['Products']=df.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))
# Out:
# <ipython-input-112-5e20f39e1ce1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Products']=df.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))

# %%
 df = df[['Order ID','Products']].drop_duplicates()

# %%
df
# Out:
#       Order ID                                    Products
# 46      236716  AA Batteries (4-pack),USB-C Charging Cable
# 60      236729             iPhone,Apple Airpods Headphones
# 62      236730               Google Phone,Wired Headphones
# 132     236799               Google Phone,Wired Headphones
# 163     236829        Vareebadd Phone,USB-C Charging Cable
# ...        ...                                         ...
# 18291   194008      AA Batteries (4-pack),Wired Headphones
# 18305   194021               Google Phone,Wired Headphones
# 18335   194050  AA Batteries (4-pack),USB-C Charging Cable
# 18342   194056             iPhone,Lightning Charging Cable
# 18348   194061             iPhone,Lightning Charging Cable
#
# [7136 rows x 2 columns]

# %%
## https://stackoverflow.com/questions/52195887/counting-unique-pairs-of-numbers-into-a-python-dictionary

count = Counter()

for row in df['Products']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list,2)))

for key, value in count.most_common(10):
    print(key,value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# ## from here we know two product that mostly purchase together is iPhone and Lightning Charging Cable

# %%
sales_product = all_data.groupby('Product').sum()
plt.figure(figsize=(15,12))
plt.bar(sales_product.index, sales_product['Quantity Ordered'])
plt.xticks(sales_product.index,rotation ='vertical', size=15)
plt.xlabel('Product',size=15)
plt.ylabel('count',size=15)
plt.grid()

# %%
plt.figure(figsize=(15,12))
plt.bar(sales_product.index, sales_product['Sales'])
plt.xticks(sales_product.index,rotation ='vertical', size=15)
plt.xlabel('Product',size=15)
plt.ylabel('Sales in million',size=15)
plt.grid()
