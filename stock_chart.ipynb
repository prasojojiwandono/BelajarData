# %%
import plotly.graph_objects as go
import plotly
import pandas as pd

# %%
df_saham = pd.read_excel('/home/prasojo/belajar/BelajarData/dataset/buat_test_saham_aja.xlsx')

# %%
df_saham.head()
# Out:
#     JII        date   Open   High    Low  Close   Volume
# 0  AALI  2020-11-23  11025  11100  10900  10975  1841700
# 1  AALI  2020-11-20  10975  11275  10975  11000  4112100
# 2  AALI  2020-11-19  11000  11075  10975  10975  2141300
# 3  AALI  2020-11-18  11000  11100  10950  10950  1620900
# 4  AALI  2020-11-17  11200  11225  10950  10975  3592600

# %%
df_saham = df_saham.reindex(index=df_saham.index[::-1])

# %%
df_saham = df_saham.set_index(pd.DatetimeIndex(df_saham['date'].values))

# %%
df_saham
# Out:
#              JII        date   Open   High    Low  Close   Volume
# 2020-08-10  AALI  2020-08-10   9850  10125   9750  10125  3044700
# 2020-08-11  AALI  2020-08-11  10100  10225  10000  10175  2096800
# 2020-08-12  AALI  2020-08-12  10100  10200   9850  10000  2736100
# 2020-08-13  AALI  2020-08-13  10175  10425  10075  10150  2707700
# 2020-08-14  AALI  2020-08-14  10175  10325  10150  10275  1581600
# ...          ...         ...    ...    ...    ...    ...      ...
# 2020-11-17  AALI  2020-11-17  11200  11225  10950  10975  3592600
# 2020-11-18  AALI  2020-11-18  11000  11100  10950  10950  1620900
# 2020-11-19  AALI  2020-11-19  11000  11075  10975  10975  2141300
# 2020-11-20  AALI  2020-11-20  10975  11275  10975  11000  4112100
# 2020-11-23  AALI  2020-11-23  11025  11100  10900  10975  1841700
#
# [70 rows x 7 columns]

# %%
figure = go.Figure(
    data =[
        go.Candlestick(
        x = df_saham.index,
        low = df_saham['Low'],
        high = df_saham['High'],
        close = df_saham['Close'],
        open = df_saham['Open'],
        increasing_line_color = 'green',
        decreasing_line_color = 'red',
        )
    ],
    layout=go.Layout(
        title=go.layout.Title(text="AALI")
    )
    
)

# figure.update_layout(
#     title = 'AALI'
# )

figure.show()
go.Candlestick()
# Out:
# <div>                            <div id="72f97c50-0215-4d40-93d0-5d7657a61da9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72f97c50-0215-4d40-93d0-5d7657a61da9")) {                    Plotly.newPlot(                        "72f97c50-0215-4d40-93d0-5d7657a61da9",                        [{"close": [10125, 10175, 10000, 10150, 10275, 10225, 10225, 9950, 9975, 10075, 10025, 10125, 10175, 10400, 11000, 11200, 11225, 11375, 11200, 10525, 9825, 10450, 10975, 10925, 10800, 10800, 10075, 10650, 10375, 10200, 9750, 9975, 9825, 9800, 10175, 10675, 10500, 10475, 10425, 10375, 10675, 10925, 11100, 11125, 11050, 10950, 11000, 10875, 10825, 10750, 10350, 10475, 10550, 10875, 10600, 10750, 10550, 10775, 10900, 10700, 10775, 10750, 11100, 11150, 11175, 10975, 1
# ...

# %%
figure.write_image(file = '/home/prasojo/belajar/BelajarData/dataset/AALI.png',
                  width = 1600,
                  height = 1000)
# plotly.offline.plot(figure, filename='/home/prasojo/belajar/BelajarData/dataset/AALI.png')
# figure.to_image(format="png")

# %%
# img_bytes = figure.to_image(format="png", width=600, height=350, scale=2)
